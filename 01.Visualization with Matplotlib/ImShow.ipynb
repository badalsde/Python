# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import matplotlib.image as mpimg

# %%
img = mpimg.imread("Image/India.png") 
print(img)
# Out:
# [[[1.         0.6        0.2       ]
#   [1.         0.6        0.2       ]
#   [1.         0.6        0.2       ]
#   ...
#   [1.         0.6        0.2       ]
#   [1.         0.6        0.2       ]
#   [1.         0.6        0.2       ]]
#
#  [[1.         0.6        0.2       ]
#   [1.         0.6        0.2       ]
#   [1.         0.6        0.2       ]
#   ...
#   [1.         0.6        0.2       ]
#   [1.         0.6        0.2       ]
#   [1.         0.6        0.2       ]]
#
#  [[1.         0.6        0.2       ]
#   [1.         0.6        0.2       ]
#   [1.         0.6        0.2       ]
#   ...
#   [1.         0.6        0.2       ]
#   [1.         0.6        0.2       ]
#   [1.         0.6        0.2       ]]
#
#  ...
#
#  [[0.07058824 0.53333336 0.02745098]
#   [0.07058824 0.53333336 0.02745098]
#   [0.07058824 0.53333336 0.02745098]
#   ...
#   [0.07058824 0.53333336 0.02745098]
#   [0.07058824 0.53333336 0.02745098]
#   [0.07058824 0.53333336 0.02745098]]
#
#  [[0.07058824 0.53333336 0.02745098]
#   [0.07058824 0.53333336 0.02745098]
#   [0.07058824 0.53333336 0.02745098]
#   ...
#   [0.07058824 0.53333336 0.02745098]
#   [0.07058824 0.53333336 0.02745098]
#   [0.07058824 0.53333336 0.02745098]]
#
#  [[0.07058824 0.53333336 0.02745098]
#   [0.07058824 0.53333336 0.02745098]
#   [0.07058824 0.53333336 0.02745098]
#   ...
#   [0.07058824 0.53333336 0.02745098]
#   [0.07058824 0.53333336 0.02745098]
#   [0.07058824 0.53333336 0.02745098]]]

# %%
img.ndim
# Out:
# 3

# %%
img.shape
# Out:
# (800, 1200, 3)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
plt.imshow(img)
plt.show()

# %%
plt.figure(figsize=(16,9))
plt.axis("off")
plt.imshow(img)
plt.colorbar() 
plt.show()

# %%
img2 = mpimg.imread("Image/India.png")
plt.figure(figsize=(16,9))
plt.axis("off")
plt.imshow(img2)
plt.colorbar()
plt.show()

# %%
single_channel2_img = img2[:,:,1]
plt.figure(figsize=(16,9))
plt.axis("off")
plt.imshow(single_channel2_img, cmap="hot")
plt.colorbar()
plt.savefig("Image/Tringa.png")
plt.show()

# %%
single_channel = img[:,:,1] # get single channel data from img
plt.figure(figsize=(16,9))
plt.axis("off")
plt.imshow(single_channel, cmap = "hot") 
plt.colorbar()
plt.show()

# %%
cmap = """Accent, Accent_r, Blues, Blues_r, BrBG, BrBG_r, BuGn, BuGn_r, BuPu, BuPu_r, CMRmap, CMRmap_r, Dark2, Dark2_r, GnBu, GnBu_r, Greens, Greens_r, Greys, Greys_r, OrRd, OrRd_r, Oranges, Oranges_r, PRGn, PRGn_r, Paired, Paired_r, Pastel1, Pastel1_r, Pastel2, Pastel2_r, PiYG, PiYG_r, PuBu, PuBuGn, PuBuGn_r, PuBu_r, PuOr, PuOr_r, PuRd, PuRd_r, Purples, Purples_r, RdBu, RdBu_r, RdGy, RdGy_r, RdPu, RdPu_r, RdYlBu, RdYlBu_r, RdYlGn, RdYlGn_r, Reds, Reds_r, Set1, Set1_r, Set2, Set2_r, Set3, Set3_r, Spectral, Spectral_r, Wistia, Wistia_r, YlGn, YlGnBu, YlGnBu_r, YlGn_r, YlOrBr, YlOrBr_r, YlOrRd, YlOrRd_r, afmhot, afmhot_r, autumn, autumn_r, binary, binary_r, bone, bone_r, brg, brg_r, bwr, bwr_r, cividis, cividis_r, cool, cool_r, coolwarm, coolwarm_r, copper, copper_r, cubehelix, cubehelix_r, flag, flag_r, gist_earth, gist_earth_r, gist_gray, gist_gray_r, gist_heat, gist_heat_r, gist_ncar, gist_ncar_r, gist_rainbow, gist_rainbow_r, gist_stern, gist_stern_r, gist_yarg, gist_yarg_r, gnuplot, gnuplot2, gnuplot2_r, gnuplot_r, gray, gray_r, hot, hot_r, hsv, hsv_r, inferno, inferno_r, jet, jet_r, magma, magma_r, nipy_spectral, nipy_spectral_r, ocean, ocean_r, pink, pink_r, plasma, plasma_r, prism, prism_r, rainbow, rainbow_r, seismic, seismic_r, spring, spring_r, summer, summer_r, tab10, tab10_r, tab20, tab20_r, tab20b, tab20b_r, tab20c, tab20c_r, terrain, terrain_r, twilight, twilight_r, twilight_shifted, twilight_shifted_r, viridis, viridis_r, winter, winter_r"""

badal = cmap.split(sep = ", ")

# %%
print(badal)
# Out:
# ['Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'cubehelix', 'cubehelix_r', 'flag', 'flag_r', 'gist_earth', 'gist_earth_r', 'gist_gray', 'gist_gray_r', 'gist_heat', 'gist_heat_r', 'gist_ncar', 'gist_ncar_r', 'gist_rainbow', 'gist_rainbow_r', 'gist_stern', 'gist_stern_r', 'gist_yarg', 'gist_yarg_r', 'gnuplot', 'gnuplot2', 'gnuplot2_r', 'gnuplot_r', 'gray', 'gray_r', 'hot', 'hot_r', 'hsv', 'hsv_r', 'inferno', 'inferno_r', 'jet', 'jet_r', 'magma', 'magma_r', 'nipy_spectral', 'nipy_spectral_r', 'ocean', 'ocean_r', 'pink', 'pink_r', 'plasma', 'plasma_r', 'prism', 'prism_r', 'rainbow', 'rainbow_r', 'seismic', 'seismic_r', 'spring', 'spring_r', 'summer', 'summer_r', 'tab10', 'tab10_r', 'tab20', 'tab20_r', 'tab20b', 'tab20b_r', 'tab20c', 'tab20c_r', 'terrain', 'terrain_r', 'twilight', 'twilight_r', 'twilight_shifted', 'twilight_shifted_r', 'viridis', 'viridis_r', 'winter', 'winter_r']

# %%
save_image_addr_name = []
for i in range(len(badal)):
    cmap_str = badal[i]
    save_image_addr_name.append("Image/Output_Images/"+"India" + badal[i] + ".png")
    print(save_image_addr_name[i])
# Out:
# Image/Output_Images/IndiaAccent.png
# Image/Output_Images/IndiaAccent_r.png
# Image/Output_Images/IndiaBlues.png
# Image/Output_Images/IndiaBlues_r.png
# Image/Output_Images/IndiaBrBG.png
# Image/Output_Images/IndiaBrBG_r.png
# Image/Output_Images/IndiaBuGn.png
# Image/Output_Images/IndiaBuGn_r.png
# Image/Output_Images/IndiaBuPu.png
# Image/Output_Images/IndiaBuPu_r.png
# Image/Output_Images/IndiaCMRmap.png
# Image/Output_Images/IndiaCMRmap_r.png
# Image/Output_Images/IndiaDark2.png
# Image/Output_Images/IndiaDark2_r.png
# Image/Output_Images/IndiaGnBu.png
# Image/Output_Images/IndiaGnBu_r.png
# Image/Output_Images/IndiaGreens.png
# Image/Output_Images/IndiaGreens_r.png
# Image/Output_Images/IndiaGreys.png
# Image/Output_Images/IndiaGreys_r.png
# Image/Output_Images/IndiaOrRd.png
# Image/Output_Images/IndiaOrRd_r.png
# Image/Output_Images/IndiaOranges.png
# Image/Output_Images/IndiaOranges_r.png
# Image/Output_Images/IndiaPRGn.png
# Image/Output_Images/IndiaPRGn_r.png
# Image/Output_Images/IndiaPaired.png
# Image/Output_Images/IndiaPaired_r.png
# Image/Output_Images/IndiaPastel1.png
# Image/Output_Images/IndiaPastel1_r.png
# Image/Output_Images/IndiaPastel2.png
# Image/Output_Images/IndiaPastel2_r.png
# Image/Output_Images/IndiaPiYG.png
# Image/Output_Images/IndiaPiYG_r.png
# Image/Output_Images/IndiaPuBu.png
# Image/Output_Images/IndiaPuBuGn.png
# Image/Output_Images/IndiaPuBuGn_r.png
# Image/Output_Images/IndiaPuBu_r.png
# Image/Output_Images/IndiaPuOr.png
# Image/Output_Images/IndiaPuOr_r.png
# Image/Output_Images/IndiaPuRd.png
# Image/Output_Images/IndiaPuRd_r.png
# Image/Output_Images/IndiaPurples.png
# Image/Output_Images/IndiaPurples_r.png
# Image/Output_Images/IndiaRdBu.png
# Image/Output_Images/IndiaRdBu_r.png
# Image/Output_Images/IndiaRdGy.png
# Image/Output_Images/IndiaRdGy_r.png
# Image/Output_Images/IndiaRdPu.png
# Image/Output_Images/IndiaRdPu_r.png
# Image/Output_Images/IndiaRdYlBu.png
# Image/Output_Images/IndiaRdYlBu_r.png
# Image/Output_Images/IndiaRdYlGn.png
# Image/Output_Images/IndiaRdYlGn_r.png
# Image/Output_Images/IndiaReds.png
# Image/Output_Images/IndiaReds_r.png
# Image/Output_Images/IndiaSet1.png
# Image/Output_Images/IndiaSet1_r.png
# Image/Output_Images/IndiaSet2.png
# Image/Output_Images/IndiaSet2_r.png
# Image/Output_Images/IndiaSet3.png
# Image/Output_Images/IndiaSet3_r.png
# Image/Output_Images/IndiaSpectral.png
# Image/Output_Images/IndiaSpectral_r.png
# Image/Output_Images/IndiaWistia.png
# Image/Output_Images/IndiaWistia_r.png
# Image/Output_Images/IndiaYlGn.png
# Image/Output_Images/IndiaYlGnBu.png
# Image/Output_Images/IndiaYlGnBu_r.png
# Image/Output_Images/IndiaYlGn_r.png
# Image/Output_Images/IndiaYlOrBr.png
# Image/Output_Images/IndiaYlOrBr_r.png
# Image/Output_Images/IndiaYlOrRd.png
# Image/Output_Images/IndiaYlOrRd_r.png
# Image/Output_Images/Indiaafmhot.png
# Image/Output_Images/Indiaafmhot_r.png
# Image/Output_Images/Indiaautumn.png
# Image/Output_Images/Indiaautumn_r.png
# Image/Output_Images/Indiabinary.png
# Image/Output_Images/Indiabinary_r.png
# Image/Output_Images/Indiabone.png
# Image/Output_Images/Indiabone_r.png
# Image/Output_Images/Indiabrg.png
# Image/Output_Images/Indiabrg_r.png
# Image/Output_Images/Indiabwr.png
# Image/Output_Images/Indiabwr_r.png
# Image/Output_Images/Indiacividis.png
# Image/Output_Images/Indiacividis_r.png
# Image/Output_Images/Indiacool.png
# Image/Output_Images/Indiacool_r.png
# Image/Output_Images/Indiacoolwarm.png
# Image/Output_Images/Indiacoolwarm_r.png
# Image/Output_Images/Indiacopper.png
# Image/Output_Images/Indiacopper_r.png
# Image/Output_Images/Indiacubehelix.png
# Image/Output_Images/Indiacubehelix_r.png
# Image/Output_Images/Indiaflag.png
# Image/Output_Images/Indiaflag_r.png
# Image/Output_Images/Indiagist_earth.png
# Image/Output_Images/Indiagist_earth_r.png
# Image/Output_Images/Indiagist_gray.png
# Image/Output_Images/Indiagist_gray_r.png
# Image/Output_Images/Indiagist_heat.png
# Image/Output_Images/Indiagist_heat_r.png
# Image/Output_Images/Indiagist_ncar.png
# Image/Output_Images/Indiagist_ncar_r.png
# Image/Output_Images/Indiagist_rainbow.png
# Image/Output_Images/Indiagist_rainbow_r.png
# Image/Output_Images/Indiagist_stern.png
# Image/Output_Images/Indiagist_stern_r.png
# Image/Output_Images/Indiagist_yarg.png
# Image/Output_Images/Indiagist_yarg_r.png
# Image/Output_Images/Indiagnuplot.png
# Image/Output_Images/Indiagnuplot2.png
# Image/Output_Images/Indiagnuplot2_r.png
# Image/Output_Images/Indiagnuplot_r.png
# Image/Output_Images/Indiagray.png
# Image/Output_Images/Indiagray_r.png
# Image/Output_Images/Indiahot.png
# Image/Output_Images/Indiahot_r.png
# Image/Output_Images/Indiahsv.png
# Image/Output_Images/Indiahsv_r.png
# Image/Output_Images/Indiainferno.png
# Image/Output_Images/Indiainferno_r.png
# Image/Output_Images/Indiajet.png
# Image/Output_Images/Indiajet_r.png
# Image/Output_Images/Indiamagma.png
# Image/Output_Images/Indiamagma_r.png
# Image/Output_Images/Indianipy_spectral.png
# Image/Output_Images/Indianipy_spectral_r.png
# Image/Output_Images/Indiaocean.png
# Image/Output_Images/Indiaocean_r.png
# Image/Output_Images/Indiapink.png
# Image/Output_Images/Indiapink_r.png
# Image/Output_Images/Indiaplasma.png
# Image/Output_Images/Indiaplasma_r.png
# Image/Output_Images/Indiaprism.png
# Image/Output_Images/Indiaprism_r.png
# Image/Output_Images/Indiarainbow.png
# Image/Output_Images/Indiarainbow_r.png
# Image/Output_Images/Indiaseismic.png
# Image/Output_Images/Indiaseismic_r.png
# Image/Output_Images/Indiaspring.png
# Image/Output_Images/Indiaspring_r.png
# Image/Output_Images/Indiasummer.png
# Image/Output_Images/Indiasummer_r.png
# Image/Output_Images/Indiatab10.png
# Image/Output_Images/Indiatab10_r.png
# Image/Output_Images/Indiatab20.png
# Image/Output_Images/Indiatab20_r.png
# Image/Output_Images/Indiatab20b.png
# Image/Output_Images/Indiatab20b_r.png
# Image/Output_Images/Indiatab20c.png
# Image/Output_Images/Indiatab20c_r.png
# Image/Output_Images/Indiaterrain.png
# Image/Output_Images/Indiaterrain_r.png
# Image/Output_Images/Indiatwilight.png
# Image/Output_Images/Indiatwilight_r.png
# Image/Output_Images/Indiatwilight_shifted.png
# Image/Output_Images/Indiatwilight_shifted_r.png
# Image/Output_Images/Indiaviridis.png
# Image/Output_Images/Indiaviridis_r.png
# Image/Output_Images/Indiawinter.png
# Image/Output_Images/Indiawinter_r.png

# %%
for i in range(len(badal)): 
    cmap_name = badal[i]
    plt.figure(figsize=(16,9))
    plt.axis("off")
     
    print(cmap_name)
 
    plt.imshow(single_channel2_img, cmap=cmap_name)
    #plt.colorbar()
    #save_image_name1 = "D:\\cmap_image\\"+"girl" + cmap_list[i]
    print(save_image_addr_name[i])
    plt.savefig(save_image_addr_name[i], orientation='portrate', facecolor= "k")
    plt.show()
# Out:
# Accent
# Image/Output_Images/IndiaAccent.png
# Accent_r
# Image/Output_Images/IndiaAccent_r.png
# Blues
# Image/Output_Images/IndiaBlues.png
# Blues_r
# Image/Output_Images/IndiaBlues_r.png
# BrBG
# Image/Output_Images/IndiaBrBG.png
# BrBG_r
# Image/Output_Images/IndiaBrBG_r.png
# BuGn
# Image/Output_Images/IndiaBuGn.png
# BuGn_r
# Image/Output_Images/IndiaBuGn_r.png
# BuPu
# Image/Output_Images/IndiaBuPu.png
# BuPu_r
# Image/Output_Images/IndiaBuPu_r.png
# CMRmap
# Image/Output_Images/IndiaCMRmap.png
# CMRmap_r
# Image/Output_Images/IndiaCMRmap_r.png
# Dark2
# Image/Output_Images/IndiaDark2.png
# Dark2_r
# Image/Output_Images/IndiaDark2_r.png
# GnBu
# Image/Output_Images/IndiaGnBu.png
# GnBu_r
# Image/Output_Images/IndiaGnBu_r.png
# Greens
# Image/Output_Images/IndiaGreens.png
# Greens_r
# Image/Output_Images/IndiaGreens_r.png
# Greys
# Image/Output_Images/IndiaGreys.png
# Greys_r
# Image/Output_Images/IndiaGreys_r.png
# OrRd
# Image/Output_Images/IndiaOrRd.png
# OrRd_r
# Image/Output_Images/IndiaOrRd_r.png
# Oranges
# Image/Output_Images/IndiaOranges.png
# Oranges_r
# Image/Output_Images/IndiaOranges_r.png
# PRGn
# Image/Output_Images/IndiaPRGn.png
# PRGn_r
# Image/Output_Images/IndiaPRGn_r.png
# Paired
# Image/Output_Images/IndiaPaired.png
# Paired_r
# Image/Output_Images/IndiaPaired_r.png
# Pastel1
# Image/Output_Images/IndiaPastel1.png
# Pastel1_r
# Image/Output_Images/IndiaPastel1_r.png
